# %% [markdown]
# <div align="center">
#
# ## Assignment 1 - Introduction to Deep Learning
# ### Tsinghua University
#
# **Allan Li**
#
# </div>

# %% [markdown]
# ## Problem 0 Objective Questions
#
# 0.1: B
#
# 0.2: B
#
# 0.3: A

# %% [markdown]
# ## Problem 1

# %%
list1 = [10, 20, 30, 40, 50]
reversed_list = []

for i in range(len(list1)-1, -1, -1):
    reversed_list.append(list1[i])

list1 = reversed_list

print(list1)
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# ## Problem 2

# %%
d1 = {"a":100,"b":200,"c":300}
d2 = {"a":300,"b":200,"d":400}
d3 = {}

def insertDict(dictToInsert, globalDict):
    for key, value in dictToInsert.items():
        if key in globalDict:
            globalDict[key] += value
        else:
            globalDict[key] = value
    return globalDict

d3 = insertDict(d1, d3)
d3 = insertDict(d2, d3)

print(d3)
# Out:
# {'a': 400, 'b': 400, 'c': 300, 'd': 400}

# %% [markdown]
# ## Problem 3

# %%
import math

class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    # prints the point out
    def show(self):
        print("(" + str(self.x) + ", " + str(self.y) + ")")
    
    def dist(self, otherPoint):
        xDist = abs(self.x - otherPoint.x)
        yDist = abs(self.y - otherPoint.y)
        return math.sqrt(xDist ** 2 + yDist ** 2)


# demonstration of functions
p1 = Point(0, 0)
p2 = Point(10, 10)

p1.show()
p2.show()
print(p1.dist(p2))
print(p2.dist(p1))
# Out:
# (0, 0)
# (10, 10)
# 14.142135623730951
# 14.142135623730951

# %% [markdown]
# ## Problem 4

# %%
import numpy as np

A = np.random.normal(loc = 0, scale = 1, size = (4, 4)) 

print(A[1:3, 1:3])

columnMax = A.max(axis = 0)
rowMax = A.min(axis = 1)

print(columnMax)
print(rowMax)

averageCol2 = A[:, 2].mean()
averageRow3 = A[3, :].mean()
averageAll = A.mean()

print(averageCol2)
print(averageRow3)
print(averageAll)
# Out:
# [[ 0.32810858 -0.4178712 ]
#  [-1.00041707  0.21930163]]
# [1.31375515 0.32810858 0.21930163 0.18858774]
# [-0.32083647 -0.4178712  -1.00041707 -1.92425219]
# -0.12362776784909348
# -0.5818074365044013
# -0.11454289977363241

# %% [markdown]
# ## Problem 5
